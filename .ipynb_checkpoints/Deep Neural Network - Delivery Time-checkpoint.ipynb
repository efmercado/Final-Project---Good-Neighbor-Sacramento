# %%
# Importing dependencies
import pandas as pd
import requests

# %% [markdown]
# # Reading the CSV

# %%
# Reading CSV file
df = pd.read_csv('sac_crime.csv')

df.head()
# Out:
#   Beat                     Description  Grid               Occurence_Date  \
# 0   3B     487(A) PC GRAND THEFT >$950   748  Wed 01-01-2020, 01:15:00 AM
# 1   3B              484 PC PETTY THEFT   748  Wed 01-01-2020, 01:30:00 AM
# 2   3A             459 PC BURG VEHICLE   725  Wed 01-01-2020, 10:40:00 AM
# 3   4A  459.5 BURGLARY SHOPLIFT < $950   965  Wed 01-01-2020, 02:30:00 PM
# 4   4A  459.5 BURGLARY SHOPLIFT < $950   965  Wed 01-01-2020, 02:10:00 PM
#
#   Offense_Category  Offense_Code Offense_Ext  Police_District  Record_ID  \
# 0          LARCENY          2303           1                3    1429889
# 1          LARCENY          2399           2                3    1429894
# 2         BURGLARY          2299          01                3    1429896
# 3         BURGLARY          2205           3                4    1429900
# 4         BURGLARY          2205           3                4    1429902
#
#    Day_of_the_Week  Month  Year  Hour  Encoded_Beat
# 0                3      1  2020     1             7
# 1                3      1  2020     1             7
# 2                3      1  2020    10             6
# 3                3      1  2020    14             9
# 4                3      1  2020    14             9

# %%
# Setting features
selected_features = df[['Offense_Category','Encoded_Beat','Police_District','Grid',
                        'Day_of_the_Week','Month','Year','Hour']]
selected_features.head()
# Out:
#   Offense_Category  Encoded_Beat  Police_District  Grid  Day_of_the_Week  \
# 0          LARCENY             7                3   748                3
# 1          LARCENY             7                3   748                3
# 2         BURGLARY             6                3   725                3
# 3         BURGLARY             9                4   965                3
# 4         BURGLARY             9                4   965                3
#
#    Month  Year  Hour
# 0      1  2020     1
# 1      1  2020     1
# 2      1  2020    10
# 3      1  2020    14
# 4      1  2020    14

# %% [markdown]
# # Data Preprocessing

# %%
# Assigning X and y values
X = selected_features.drop('Offense_Category', axis=1)
y = selected_features['Offense_Category']

print(X.shape, y.shape)
# Out:
# (5835, 7) (5835,)

# %%
# Importing dependencies
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# Splitting data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Creating a MinMaxScaler model and fitting it to the training data
X_scaler = MinMaxScaler().fit(X_train)

# Transform the training and testing data using the X_scaler
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Creating a LabelEncoder model and fitting it to y training data
label_encoder = LabelEncoder()
label_encoder.fit(y)

# Encoding y data
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# One-hot encoding y
one_hot_y_train = to_categorical(encoded_y_train)
one_hot_y_test = to_categorical(encoded_y_test)
one_hot_y_train.shape
# Out:
# (4376, 10)

# %% [markdown]
# # Building a Deep Neural Network Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Creating an empty sequential model
deep_model = Sequential()

# %%
# Adding layers
deep_model.add(Dense(units=100, activation="relu", input_dim=7))
deep_model.add(Dense(units=100, activation='relu'))
deep_model.add(Dense(units=10, activation='softmax'))

# %%
deep_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               800
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 11,910
# Trainable params: 11,910
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
deep_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Using the training data to fit and train the deep model
deep_model.fit(X_train_scaled, one_hot_y_train, epochs=100, shuffle=True, verbose=2)
# Out:
# Train on 4376 samples
# Epoch 1/100
# 4376/4376 - 1s - loss: 1.4126 - accuracy: 0.4394
# Epoch 2/100
# 4376/4376 - 0s - loss: 1.2541 - accuracy: 0.4646
# Epoch 3/100
# 4376/4376 - 0s - loss: 1.2424 - accuracy: 0.4657
# Epoch 4/100
# 4376/4376 - 0s - loss: 1.2365 - accuracy: 0.4646
# Epoch 5/100
# 4376/4376 - 0s - loss: 1.2343 - accuracy: 0.4614
# Epoch 6/100
# 4376/4376 - 0s - loss: 1.2311 - accuracy: 0.4762
# Epoch 7/100
# 4376/4376 - 0s - loss: 1.2310 - accuracy: 0.4666
# Epoch 8/100
# 4376/4376 - 0s - loss: 1.2262 - accuracy: 0.4735
# Epoch 9/100
# 4376/4376 - 0s - loss: 1.2249 - accuracy: 0.4760
# Epoch 10/100
# 4376/4376 - 0s - loss: 1.2247 - accuracy: 0.4771
# Epoch 11/100
# 4376/4376 - 0s - loss: 1.2214 - accuracy: 0.4845
# Epoch 12/100
# 4376/4376 - 0s - loss: 1.2237 - accuracy: 0.4790
# Epoch 13/100
# 4376/4376 - 0s - loss: 1.2204 - accuracy: 0.4870
# Epoch 14/100
# 4376/4376 - 0s - loss: 1.2184 - accuracy: 0.4902
# Epoch 15/100
# 4376/4376 - 0s - loss: 1.2177 - accuracy: 0.4888
# Epoch 16/100
# 4376/4376 - 0s - loss: 1.2178 - accuracy: 0.4870
# Epoch 17/100
# 4376/4376 - 0s - loss: 1.2208 - accuracy: 0.4936
# Epoch 18/100
# 4376/4376 - 0s - loss: 1.2157 - accuracy: 0.4847
# Epoch 19/100
# 4376/4376 - 0s - loss: 1.2154 - accuracy: 0.4895
# Epoch 20/100
# 4376/4376 - 0s - loss: 1.2152 - accuracy: 0.4881
# Epoch 21/100
# 4376/4376 - 0s - loss: 1.2147 - accuracy: 0.4888
# Epoch 22/100
# 4376/4376 - 0s - loss: 1.2115 - accuracy: 0.4943
# Epoch 23/100
# 4376/4376 - 0s - loss: 1.2114 - accuracy: 0.4890
# Epoch 24/100
# 4376/4376 - 0s - loss: 1.2109 - accuracy: 0.4906
# Epoch 25/100
# 4376/4376 - 0s - loss: 1.2085 - accuracy: 0.4881
# Epoch 26/100
# 4376/4376 - 0s - loss: 1.2101 - accuracy: 0.4909
# Epoch 27/100
# 4376/4376 - 0s - loss: 1.2044 - accuracy: 0.4975
# Epoch 28/100
# 4376/4376 - 0s - loss: 1.2045 - accuracy: 0.4941
# Epoch 29/100
# 4376/4376 - 0s - loss: 1.2037 - accuracy: 0.4909
# Epoch 30/100
# 4376/4376 - 0s - loss: 1.2040 - accuracy: 0.4961
# Epoch 31/100
# 4376/4376 - 0s - loss: 1.2036 - accuracy: 0.5009
# Epoch 32/100
# 4376/4376 - 0s - loss: 1.2012 - accuracy: 0.5039
# Epoch 33/100
# 4376/4376 - 0s - loss: 1.1994 - accuracy: 0.4920
# Epoch 34/100
# 4376/4376 - 0s - loss: 1.1980 - accuracy: 0.4966
# Epoch 35/100
# 4376/4376 - 0s - loss: 1.1995 - accuracy: 0.4954
# Epoch 36/100
# 4376/4376 - 0s - loss: 1.1965 - accuracy: 0.4975
# Epoch 37/100
# 4376/4376 - 0s - loss: 1.1961 - accuracy: 0.4989
# Epoch 38/100
# 4376/4376 - 0s - loss: 1.1938 - accuracy: 0.5018
# Epoch 39/100
# 4376/4376 - 0s - loss: 1.1943 - accuracy: 0.5005
# Epoch 40/100
# 4376/4376 - 0s - loss: 1.1907 - accuracy: 0.5087
# Epoch 41/100
# 4376/4376 - 0s - loss: 1.1918 - accuracy: 0.5027
# Epoch 42/100
# 4376/4376 - 0s - loss: 1.1903 - accuracy: 0.4989
# Epoch 43/100
# 4376/4376 - 0s - loss: 1.1899 - accuracy: 0.5055
# Epoch 44/100
# 4376/4376 - 0s - loss: 1.1890 - accuracy: 0.5000
# Epoch 45/100
# 4376/4376 - 0s - loss: 1.1869 - accuracy: 0.5098
# Epoch 46/100
# 4376/4376 - 0s - loss: 1.1852 - accuracy: 0.5025
# Epoch 47/100
# 4376/4376 - 0s - loss: 1.1840 - accuracy: 0.5000
# Epoch 48/100
# 4376/4376 - 0s - loss: 1.1862 - accuracy: 0.5101
# Epoch 49/100
# 4376/4376 - 0s - loss: 1.1849 - accuracy: 0.5030
# Epoch 50/100
# 4376/4376 - 0s - loss: 1.1824 - accuracy: 0.5059
# Epoch 51/100
# 4376/4376 - 0s - loss: 1.1842 - accuracy: 0.5037
# Epoch 52/100
# 4376/4376 - 0s - loss: 1.1820 - accuracy: 0.5057
# Epoch 53/100
# 4376/4376 - 0s - loss: 1.1794 - accuracy: 0.5009
# Epoch 54/100
# 4376/4376 - 0s - loss: 1.1785 - accuracy: 0.5080
# Epoch 55/100
# 4376/4376 - 0s - loss: 1.1802 - accuracy: 0.5082
# Epoch 56/100
# 4376/4376 - 0s - loss: 1.1785 - accuracy: 0.5082
# Epoch 57/100
# 4376/4376 - 0s - loss: 1.1782 - accuracy: 0.5101
# Epoch 58/100
# 4376/4376 - 0s - loss: 1.1762 - accuracy: 0.5110
# Epoch 59/100
# 4376/4376 - 0s - loss: 1.1736 - accuracy: 0.5103
# Epoch 60/100
# 4376/4376 - 0s - loss: 1.1738 - accuracy: 0.5053
# Epoch 61/100
# 4376/4376 - 0s - loss: 1.1742 - accuracy: 0.5059
# Epoch 62/100
# 4376/4376 - 0s - loss: 1.1727 - accuracy: 0.5057
# Epoch 63/100
# 4376/4376 - 0s - loss: 1.1721 - accuracy: 0.5119
# Epoch 64/100
# 4376/4376 - 0s - loss: 1.1738 - accuracy: 0.5016
# Epoch 65/100
# 4376/4376 - 0s - loss: 1.1722 - accuracy: 0.5082
# Epoch 66/100
# 4376/4376 - 0s - loss: 1.1679 - accuracy: 0.5087
# Epoch 67/100
# 4376/4376 - 0s - loss: 1.1707 - accuracy: 0.5105
# Epoch 68/100
# 4376/4376 - 0s - loss: 1.1668 - accuracy: 0.5114
# Epoch 69/100
# 4376/4376 - 0s - loss: 1.1684 - accuracy: 0.5094
# Epoch 70/100
# 4376/4376 - 0s - loss: 1.1655 - accuracy: 0.5103
# Epoch 71/100
# 4376/4376 - 0s - loss: 1.1688 - accuracy: 0.4993
# Epoch 72/100
# 4376/4376 - 0s - loss: 1.1671 - accuracy: 0.5066
# Epoch 73/100
# 4376/4376 - 0s - loss: 1.1683 - accuracy: 0.5075
# Epoch 74/100
# 4376/4376 - 0s - loss: 1.1639 - accuracy: 0.5139
# Epoch 75/100
# 4376/4376 - 0s - loss: 1.1640 - accuracy: 0.5137
# Epoch 76/100
# 4376/4376 - 0s - loss: 1.1632 - accuracy: 0.5098
# Epoch 77/100
# 4376/4376 - 0s - loss: 1.1645 - accuracy: 0.5091
# Epoch 78/100
# 4376/4376 - 0s - loss: 1.1621 - accuracy: 0.5160
# Epoch 79/100
# 4376/4376 - 0s - loss: 1.1596 - accuracy: 0.5133
# Epoch 80/100
# 4376/4376 - 0s - loss: 1.1603 - accuracy: 0.5146
# Epoch 81/100
# 4376/4376 - 0s - loss: 1.1588 - accuracy: 0.5101
# Epoch 82/100
# 4376/4376 - 0s - loss: 1.1592 - accuracy: 0.5082
# Epoch 83/100
# 4376/4376 - 0s - loss: 1.1585 - accuracy: 0.5103
# Epoch 84/100
# 4376/4376 - 0s - loss: 1.1561 - accuracy: 0.5126
# Epoch 85/100
# 4376/4376 - 0s - loss: 1.1577 - accuracy: 0.5135
# Epoch 86/100
# 4376/4376 - 0s - loss: 1.1578 - accuracy: 0.5142
# Epoch 87/100
# 4376/4376 - 0s - loss: 1.1537 - accuracy: 0.5130
# Epoch 88/100
# 4376/4376 - 0s - loss: 1.1539 - accuracy: 0.5165
# Epoch 89/100
# 4376/4376 - 0s - loss: 1.1525 - accuracy: 0.5146
# Epoch 90/100
# 4376/4376 - 0s - loss: 1.1548 - accuracy: 0.5107
# Epoch 91/100
# 4376/4376 - 0s - loss: 1.1560 - accuracy: 0.5112
# Epoch 92/100
# 4376/4376 - 0s - loss: 1.1513 - accuracy: 0.5153
# Epoch 93/100
# 4376/4376 - 0s - loss: 1.1526 - accuracy: 0.5110
# Epoch 94/100
# 4376/4376 - 0s - loss: 1.1528 - accuracy: 0.5160
# Epoch 95/100
# 4376/4376 - 0s - loss: 1.1513 - accuracy: 0.5171
# Epoch 96/100
# 4376/4376 - 0s - loss: 1.1508 - accuracy: 0.5142
# Epoch 97/100
# 4376/4376 - 0s - loss: 1.1507 - accuracy: 0.5080
# Epoch 98/100
# 4376/4376 - 0s - loss: 1.1485 - accuracy: 0.5171
# Epoch 99/100
# 4376/4376 - 0s - loss: 1.1465 - accuracy: 0.5144
# Epoch 100/100
# 4376/4376 - 0s - loss: 1.1472 - accuracy: 0.5137

# %%
# Evaluating the Deep Model
deep_model_loss, deep_model_accuracy = deep_model.evaluate(X_test_scaled, one_hot_y_test, verbose=5)
print(f'Loss: {deep_model_loss}, Accuracy: {deep_model_accuracy}')
# Out:
# Loss: 1.2919068386327575, Accuracy: 0.4941740930080414
