# %%
# Dependencies
import os
import pprint
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %% [markdown]
# ## MAC

# %%
# Set Executable Path & Initialize Chrome Browser
#executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
#browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ## Windows

# %%
# Set Executable Path & Initialize Chrome Browser
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# page = requests.get(url)
sacramento_url ='https://www.redfin.com/city/16409/CA/Sacramento/housing-market'
browser.visit(sacramento_url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
neighborhoods = {'Creekside': 'https://www.redfin.com/neighborhood/56574/CA/Sacramento/Creekside',
                 'Westlake': 'https://www.redfin.com/neighborhood/56567/CA/Sacramento/Westlake',
                 'Natomas Park': 'https://www.redfin.com/neighborhood/350822/CA/Sacramento/Natomas-Park',
                 'Regency Park': 'https://www.redfin.com/neighborhood/56443/CA/Sacramento/Regency-Park',
                 'South Natomas': 'https://www.redfin.com/neighborhood/2549/CA/Sacramento/South-Natomas',
                 'Northgate': 'https://www.redfin.com/neighborhood/1895/CA/Sacramento/Northgate',
                 'Gardenland': 'https://www.redfin.com/neighborhood/119996/CA/Sacramento/Gardenland',
                 'River Gardens': 'https://www.redfin.com/neighborhood/56481/CA/Sacramento/River-Gardens',
                 'Del Paso Heights': 'https://www.redfin.com/neighborhood/678/CA/Sacramento/Del-Paso-Heights',
                 'Robla': 'https://www.redfin.com/neighborhood/2310/CA/Sacramento/Robla',
                 'Glenwood Meadows': 'https://www.redfin.com/neighborhood/1107/CA/Sacramento/Glenwood-Meadows',
                 'East Del Paso Heights': 'https://www.redfin.com/neighborhood/119426/CA/Sacramento/East-del-Paso-Heights',
                 'Hagginwood':'https://www.redfin.com/neighborhood/115005/CA/Sacramento/Hagginwood',
                 'South Hagginwood': 'https://www.redfin.com/neighborhood/118194/CA/Sacramento/South-Hagginwood',
                 'Johnson Heights': 'https://www.redfin.com/neighborhood/1393/CA/Sacramento/Johnson-Heights',
                 'Noralto': 'https://www.redfin.com/neighborhood/112690/CA/Sacramento/Noralto',
                 'Ben Ali': 'https://www.redfin.com/neighborhood/195/CA/Sacramento/Ben-Ali',
                 'Old North Sacramento': 'https://www.redfin.com/neighborhood/2015/CA/Sacramento/Old-North-Sacramento',
                 'Woodlake': 'https://www.redfin.com/neighborhood/3118/CA/Sacramento/Woodlake',
                 'Swanston Estates': 'https://www.redfin.com/neighborhood/2669/CA/Sacramento/Swanston-Estates',
                 'Southern Pacific Richards': 'https://www.redfin.com/neighborhood/113245/CA/Sacramento/Southern-Pacific-Richards',
                 'Dos Rios Triangle': 'https://www.redfin.com/neighborhood/711/CA/Sacramento/Dos-Rios-Triangle',
                 'Alkali Flat': 'https://www.redfin.com/neighborhood/32/CA/Sacramento/Alkali-Flat',
                 'Mansion Flats': 'https://www.redfin.com/neighborhood/1617/CA/Sacramento/Mansion-Flats',
                 'Richmond Grove': 'https://www.redfin.com/neighborhood/2268/CA/Sacramento/Richmond-Grove',
                 'Southside Park': 'https://www.redfin.com/neighborhood/2569/CA/Sacramento/Southside-Park',
                 'Midtown': 'https://www.redfin.com/neighborhood/56692/CA/Sacramento/Midtown',
                 'Newton Booth': 'https://www.redfin.com/neighborhood/1829/CA/Sacramento/Newton-Booth',
                 'Boulevard Park': 'https://www.redfin.com/neighborhood/56685/CA/Sacramento/Boulevard-Park',
                 'Avondale': 'https://www.redfin.com/neighborhood/117816/CA/Sacramento/Avondale',
                 'East Sacramento': 'https://www.redfin.com/neighborhood/834/CA/Sacramento/East-Sacramento',
                 'Alhambra Triangle': 'https://www.redfin.com/neighborhood/31/CA/Sacramento/Alhambra-Triangle',
                 'River Park': 'https://www.redfin.com/neighborhood/2291/CA/Sacramento/River-Park',
                 'Campus Commons': 'https://www.redfin.com/neighborhood/351/CA/Sacramento/Campus-Commons',
                 'College Glen': 'https://www.redfin.com/neighborhood/548148/CA/Sacramento/College-Glen',
                 'Sierra Oaks': 'https://www.redfin.com/neighborhood/42880/CA/Arden-Arcade/Sierra-Oaks'
                }

for neighborhood in neighborhoods.values():
    browser.visit(neighborhood)
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    price = soup.find_all("span", class_="homecardV2Price")
    info = soup.find_all("div", class_="stats")
    try:
        print(neighborhood)gi
        print(price)
        print(info)
    except:
        print("no listing")
        pass

# # news_p = article.find("div", class_="article_teaser_body").text
# Out:
# https://www.redfin.com/neighborhood/56574/CA/Sacramento/Creekside
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$437,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$394,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$389,000</span>]
# [<div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">2,252 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,697 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,712 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/56567/CA/Sacramento/Westlake
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$225,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$535,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$610,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$240,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$419,000</span>]
# [<div class="stats">1 Bed</div>, <div class="stats">1 Bath</div>, <div class="stats">846 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">2,350 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">2,487 Sq. Ft.</div>, <div class="stats">1 Bed</div>, <div class="stats">1 Bath</div>, <div class="stats">1,125 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">2,187 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/350822/CA/Sacramento/Natomas-Park
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$399,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$539,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$609,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$489,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$480,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$479,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$459,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$435,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$479,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$579,995</span>]
# [<div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,475 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">2,751 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3.5 Baths</div>, <div class="stats">2,935 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">2,632 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">2,102 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">2,306 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">2,265 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,906 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">2,013 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">3,052 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/56443/CA/Sacramento/Regency-Park
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$429,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$387,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$349,500</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$284,950</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$218,500</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$389,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$447,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$349,900</span>]
# [<div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,557 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,524 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,364 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">1,334 Sq. Ft.</div>, <div class="stats">1 Bed</div>, <div class="stats">1 Bath</div>, <div class="stats">763 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,492 Sq. Ft.</div>, <div class="stats">5 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,934 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,174 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/2549/CA/Sacramento/South-Natomas
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$650,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$670,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$410,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$395,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$460,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$439,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$220,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$310,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$289,970</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$369,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$335,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$369,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$344,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$384,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$425,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$420,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$365,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$506,800</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$339,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$179,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$139,000</span>]
# [<div class="stats">5 Beds</div>, <div class="stats">4 Baths</div>, <div class="stats">3,802 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">2,930 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">1,920 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">2,146 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,789 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">1,992 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,035 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,344 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,126 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,402 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,511 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,552 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,311 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,602 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">2,261 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">1,985 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,336 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3.5 Baths</div>, <div class="stats">2,431 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,285 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">1.5 Baths</div>, <div class="stats">1,276 Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/1895/CA/Sacramento/Northgate
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$299,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$385,000</span>]
# [<div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,222 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,390 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/119996/CA/Sacramento/Gardenland
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$139,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$99,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$279,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$260,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$199,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$639,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$649,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$295,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$875,000</span>]
# [<div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">768 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">960 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">714 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">1,900 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,148 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,260 Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/56481/CA/Sacramento/River-Gardens
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$179,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$169,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$545,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$395,000</span>]
# [<div class="stats">4 Beds</div>, <div class="stats">1.5 Baths</div>, <div class="stats">1,276 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">1.5 Baths</div>, <div class="stats">1,052 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,859 Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/678/CA/Sacramento/Del-Paso-Heights
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$190,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$199,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$382,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$289,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$219,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$248,520</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$445,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$219,000</span>]
# [<div class="stats">2 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">827 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">771 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">1,804 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,113 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">1,012 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">1,138 Sq. Ft.</div>, <div class="stats">7 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">2,428 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,000 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/2310/CA/Sacramento/Robla
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$335,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$360,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$159,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$287,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$309,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$279,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$359,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$549,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$150,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$443,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$3,500,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$319,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$1,285,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$289,900+</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$299,900+</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$382,900+</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$346,900+</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$329,900+</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$315,900+</span>]
# [<div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,347 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">1,631 Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,181 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">1.5 Baths</div>, <div class="stats">1,131 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,564 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,209 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">2,145 Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>, <div class="stats">6 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">2,207 Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,670 Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,181 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,396 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">2,136 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,628 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,408 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,317 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/1107/CA/Sacramento/Glenwood-Meadows
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$94,777</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$349,900</span>]
# [<div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,220 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,865 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/119426/CA/Sacramento/East-del-Paso-Heights
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$239,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$249,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$275,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$200,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$349,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$165,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$349,990</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$129,995</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$149,995</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$429,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$84,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$89,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$249,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$90,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$99,000</span>]
# [<div class="stats">3 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">1,014 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">1,058 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,352 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">900 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">1,808 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,560 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,882 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,894 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,710 Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,200 Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/115005/CA/Sacramento/Hagginwood
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$195,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$299,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$299,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$270,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$319,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$364,999</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$59,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$74,500</span>]
# [<div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,994 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">888 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,796 Sq. Ft.</div>, <div class="stats">5 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,978 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">2,025 Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/118194/CA/Sacramento/South-Hagginwood
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$179,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$325,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$184,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$170,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$325,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$99,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$240,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$219,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$55,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$229,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$50,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$50,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$80,000</span>]
# [<div class="stats">2 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">811 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">1.5 Baths</div>, <div class="stats">1,600 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">825 Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">1,083 Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">1,153 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">768 Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">900 Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/1393/CA/Sacramento/Johnson-Heights
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$199,000</span>]
# [<div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/112690/CA/Sacramento/Noralto
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$279,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$205,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$195,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$289,000</span>]
# [<div class="stats">3 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">1,332 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">1,240 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">810 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">1,200 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/195/CA/Sacramento/Ben-Ali
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$309,950</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$260,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$260,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$960,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$58,000</span>]
# [<div class="stats">4 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,800 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,056 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,056 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">4 Baths</div>, <div class="stats">2,400 Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/2015/CA/Sacramento/Old-North-Sacramento
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$350,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$324,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$255,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$155,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$225,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$269,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$299,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$120,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$130,000</span>]
# [<div class="stats">4 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,628 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,674 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">1,191 Sq. Ft.</div>, <div class="stats">1 Bed</div>, <div class="stats">1 Bath</div>, <div class="stats">336 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">760 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">1,195 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,100 Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/3118/CA/Sacramento/Woodlake
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$524,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$575,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$414,900</span>]
# [<div class="stats">2 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,718 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">4 Baths</div>, <div class="stats">2,497 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,038 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/2669/CA/Sacramento/Swanston-Estates
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$329,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$430,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$323,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$284,950</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$279,900</span>]
# [<div class="stats">4 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,400 Sq. Ft.</div>, <div class="stats">5 Beds</div>, <div class="stats">4 Baths</div>, <div class="stats">2,711 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,518 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">710 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,121 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/113245/CA/Sacramento/Southern-Pacific-Richards
# []
# []
# https://www.redfin.com/neighborhood/711/CA/Sacramento/Dos-Rios-Triangle
# []
# []
# https://www.redfin.com/neighborhood/32/CA/Sacramento/Alkali-Flat
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$1,399,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$675,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$799,000</span>]
# [<div class="stats">6 Beds</div>, <div class="stats">5 Baths</div>, <div class="stats">5,530 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">3.5 Baths</div>, <div class="stats">1,790 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">4 Baths</div>, <div class="stats">2,200 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/1617/CA/Sacramento/Mansion-Flats
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$784,500</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$549,990</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$599,990</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$629,990</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$559,990</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$569,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$749,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$1,650,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$599,990</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$589,990+</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$614,900+</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$549,990+</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$629,990+</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$599,990+</span>]
# [<div class="stats">6 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">2,556 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,521 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,521 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">4 Baths</div>, <div class="stats">1,828 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,521 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,618 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,800 Sq. Ft.</div>, <div class="stats">8 Beds</div>, <div class="stats">7 Baths</div>, <div class="stats">3,700 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">4 Baths</div>, <div class="stats">1,618 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,704 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,521 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">4 Baths</div>, <div class="stats">1,555 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,521 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/2268/CA/Sacramento/Richmond-Grove
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$849,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$1,195,000</span>]
# [<div class="stats">2 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,372 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">4.5 Baths</div>, <div class="stats">3,284 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/2569/CA/Sacramento/Southside-Park
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$598,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$240,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$775,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$809,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$525,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$769,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$499,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$650,000</span>]
# [<div class="stats">4 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">2,040 Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">2,150 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,696 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,485 Sq. Ft.</div>, <div class="stats">5 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">2,322 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,485 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">2,200 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/56692/CA/Sacramento/Midtown
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$699,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$489,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$395,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$895,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$850,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$529,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$750,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$445,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$1,243,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$899,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$764,500</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$1,099,000</span>]
# [<div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">2,448 Sq. Ft.</div>, <div class="stats">1 Bed</div>, <div class="stats">1 Bath</div>, <div class="stats">942 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">955 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">3,123 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3.5 Baths</div>, <div class="stats">2,075 Sq. Ft.</div>, <div class="stats">1 Bed</div>, <div class="stats">1 Bath</div>, <div class="stats">942 Sq. Ft.</div>, <div class="stats">1 Bed</div>, <div class="stats">1.5 Baths</div>, <div class="stats">1,219 Sq. Ft.</div>, <div class="stats">1 Bed</div>, <div class="stats">1 Bath</div>, <div class="stats">662 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">4 Baths</div>, <div class="stats">2,214 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">4 Baths</div>, <div class="stats">2,400 Sq. Ft.</div>, <div class="stats">1 Bed</div>, <div class="stats">2 Baths</div>, <div class="stats">1,044 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">4 Baths</div>, <div class="stats">2,600 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/1829/CA/Sacramento/Newton-Booth
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$849,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$715,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$549,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$545,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$587,500</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$830,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$995,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$568,800</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$573,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$569,500</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$549,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$635,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$540,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$749,999</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$550,000</span>]
# [<div class="stats">2 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">2,125 Sq. Ft.</div>, <div class="stats">5 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">2,154 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,268 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,268 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,718 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">1,950 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">4 Baths</div>, <div class="stats">2,830 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,283 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,300 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,170 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,320 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">1,847 Sq. Ft.</div>, <div class="stats"><span class="noValue">—</span>Beds</div>, <div class="stats"><span class="noValue">—</span>Baths</div>, <div class="stats"><span class="noValue">—</span>Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">2,652 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">3.5 Baths</div>, <div class="stats">1,742 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/56685/CA/Sacramento/Boulevard-Park
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$674,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$1,395,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$519,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$1,395,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$725,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$735,000</span>]
# [<div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,638 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">5 Baths</div>, <div class="stats">4,732 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,118 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">3,746 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">2,562 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">2,655 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/56607/CA/Sacramento/Marshall-School
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$1,099,000</span>]
# [<div class="stats">4 Beds</div>, <div class="stats">4 Baths</div>, <div class="stats">2,600 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/56695/CA/Sacramento/New-Era-Park
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$550,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$700,000</span>]
# [<div class="stats">2 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">775 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,188 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/548149/CA/Sacramento/Downtown-Sacramento
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$975,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$590,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$350,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$2,075,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$347,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$374,750</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$560,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$465,000</span>]
# [<div class="stats">1 Bed</div>, <div class="stats">1 Bath</div>, <div class="stats">797 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,261 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,814 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,734 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">950 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">840 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,261 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,261 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/548150/CA/Sacramento/Land-Park
# ...
# https://www.redfin.com/neighborhood/834/CA/Sacramento/East-Sacramento
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$509,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$998,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$569,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$959,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$895,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$1,895,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$1,075,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$875,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$987,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$749,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$829,950</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$1,195,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$1,750,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$949,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$1,042,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$799,888</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$549,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$699,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$1,575,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$1,425,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$579,000</span>]
# [<div class="stats">2 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">892 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3.5 Baths</div>, <div class="stats">2,474 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">1,341 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">3.5 Baths</div>, <div class="stats">2,293 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,976 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">2,581 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">2,718 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3.5 Baths</div>, <div class="stats">2,007 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3.5 Baths</div>, <div class="stats">2,443 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">2,007 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">2,497 Sq. Ft.</div>, <div class="stats">5 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">2,268 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">2,650 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3.5 Baths</div>, <div class="stats">2,276 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">4 Baths</div>, <div class="stats">2,302 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">1,902 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,288 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,273 Sq. Ft.</div>, <div class="stats">5 Beds</div>, <div class="stats">3.5 Baths</div>, <div class="stats">3,136 Sq. Ft.</div>, <div class="stats">5 Beds</div>, <div class="stats">3.5 Baths</div>, <div class="stats">2,700 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">1,160 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/31/CA/Sacramento/Alhambra-Triangle
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$649,990</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$569,990</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$579,990</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$579,990</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$798,888</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$604,990</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$614,990</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$579,900+</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$589,900+</span>]
# [<div class="stats">2 Beds</div>, <div class="stats">3.5 Baths</div>, <div class="stats">1,828 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,450 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">3.5 Baths</div>, <div class="stats">1,792 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">3.5 Baths</div>, <div class="stats">1,792 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">2,030 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,450 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,450 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">3.5 Baths</div>, <div class="stats">1,792 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,450 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/2291/CA/Sacramento/River-Park
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$649,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$599,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$678,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$619,500</span>]
# [<div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,360 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">1.5 Baths</div>, <div class="stats">1,337 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,999 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,830 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/351/CA/Sacramento/Campus-Commons
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$495,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$695,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$459,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$425,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$449,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$474,920</span>]
# [<div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">2,137 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,954 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">1,623 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,730 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,748 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2.5 Baths</div>, <div class="stats">1,986 Sq. Ft.</div>]
# https://www.redfin.com/neighborhood/548148/CA/Sacramento/College-Glen
# [<span class="homecardV2Price" data-rf-test-name="homecard-price">$410,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$365,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$89,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$60,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$424,900</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$239,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$425,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$434,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$270,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$430,000</span>, <span class="homecardV2Price" data-rf-test-name="homecard-price">$444,950</span>]
# [<div class="stats">4 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,521 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,296 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,790 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">1 Bath</div>, <div class="stats">720 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,411 Sq. Ft.</div>, <div class="stats">2 Beds</div>, <div class="stats">1.5 Baths</div>, <div class="stats">1,014 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,649 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,634 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">1.5 Baths</div>, <div class="stats">1,191 Sq. Ft.</div>, <div class="stats">3 Beds</div>, <div class="stats">2 Baths</div>, <div class="stats">1,880 Sq. Ft.</div>, <div class="stats">4 Beds</div>, <div class="stats">3 Baths</div>, <div class="stats">1,764 Sq. Ft.</div>]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-1acca083b5e6> in <module>
#      71
#      72 for neighborhood in neighborhoods.values():
# ---> 73     browser.visit(neighborhood)
#      74     html = browser.html
#      75     soup = BeautifulSoup(html, 'html.parser')
#
# ~\Anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in visit(self, url)
#     320
#     321     def visit(self, url):
# --> 322         self.driver.get(url)
#     323
#     324     def back(self):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~\Anaconda3\lib\site-packages\splinter\driver\webdriver\remote_connection.py in patch_request(self, *args, **kwargs)
#      21     for _ in range(3):
#      22         try:
# ---> 23             return old_request(self, *args, **kwargs)
#      24         except (socket.error, HTTPException, IOError, OSError, MaxRetryError) as exc:
#      25             exception = exc
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~\Anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# ~\Anaconda3\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# ~\Anaconda3\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     322             response = conn.urlopen(method, url, **kw)
#     323         else:
# --> 324             response = conn.urlopen(method, u.request_uri, **kw)
#     325
#     326         redirect_location = redirect and response.get_redirect_location()
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1334         try:
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#    1338                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
