# %%
# Importing dependencies
import pandas as pd
import requests

# %% [markdown]
# # Reading the CSV

# %%
# Reading CSV file
df = pd.read_csv('sac_crime.csv')

df.head()
# Out:
#   Beat                     Description  Grid               Occurence_Date  \
# 0   3B     487(A) PC GRAND THEFT >$950   748  Wed 01-01-2020, 01:15:00 AM
# 1   3B              484 PC PETTY THEFT   748  Wed 01-01-2020, 01:30:00 AM
# 2   3A             459 PC BURG VEHICLE   725  Wed 01-01-2020, 10:40:00 AM
# 3   4A  459.5 BURGLARY SHOPLIFT < $950   965  Wed 01-01-2020, 02:30:00 PM
# 4   4A  459.5 BURGLARY SHOPLIFT < $950   965  Wed 01-01-2020, 02:10:00 PM
#
#   Offense_Category  Offense_Code Offense_Ext  Police_District  Record_ID  \
# 0          LARCENY          2303           1                3    1429889
# 1          LARCENY          2399           2                3    1429894
# 2         BURGLARY          2299          01                3    1429896
# 3         BURGLARY          2205           3                4    1429900
# 4         BURGLARY          2205           3                4    1429902
#
#    Day_of_the_Week  Month  Year  Hour  Encoded_Beat
# 0                3      1  2020     1             7
# 1                3      1  2020     1             7
# 2                3      1  2020    10             6
# 3                3      1  2020    14             9
# 4                3      1  2020    14             9

# %%
# Setting features
selected_features = df[['Offense_Category','Encoded_Beat','Police_District','Grid',
                        'Day_of_the_Week','Month','Year','Hour']]
selected_features.head()
# Out:
#   Offense_Category  Encoded_Beat  Police_District  Grid  Day_of_the_Week  \
# 0          LARCENY             7                3   748                3
# 1          LARCENY             7                3   748                3
# 2         BURGLARY             6                3   725                3
# 3         BURGLARY             9                4   965                3
# 4         BURGLARY             9                4   965                3
#
#    Month  Year  Hour
# 0      1  2020     1
# 1      1  2020     1
# 2      1  2020    10
# 3      1  2020    14
# 4      1  2020    14

# %% [markdown]
# # Data Preprocessing

# %%
# Assigning X and y values
X = selected_features.drop('Offense_Category', axis=1)
y = selected_features['Offense_Category']

print(X.shape, y.shape)
# Out:
# (5835, 7) (5835,)

# %%
# Importing dependencies
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler

# Splitting data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Creating a MinMaxScaler model and fitting it to the training data
X_scaler = MinMaxScaler().fit(X_train)

# Transform the training and testing data using the X_scaler
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Creating a LabelEncoder model and fitting it to y training data
label_encoder = LabelEncoder()
label_encoder.fit(y)

# Encoding y data
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# One-hot encoding y
one_hot_y_train = to_categorical(encoded_y_train)
one_hot_y_test = to_categorical(encoded_y_test)
one_hot_y_train.shape
# Out:
# (4376, 10)

# %% [markdown]
# # Building a Deep Neural Network Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Creating an empty sequential model
deep_model = Sequential()

# %%
# Adding layers
deep_model.add(Dense(units=100, activation="relu", input_dim=7))
deep_model.add(Dense(units=100, activation='relu'))
deep_model.add(Dense(units=10, activation='softmax'))

# %%
deep_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 100)               800
# _________________________________________________________________
# dense_7 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 11,910
# Trainable params: 11,910
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
deep_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'], run_eagerly=True)

# %%
# Using the training data to fit and train the deep model
deep_model.fit(X_train_scaled, one_hot_y_train, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 137/137 - 2s - loss: 1.4206 - accuracy: 0.4413
# Epoch 2/100
# 137/137 - 2s - loss: 1.2550 - accuracy: 0.4456
# Epoch 3/100
# 137/137 - 2s - loss: 1.2425 - accuracy: 0.4484
# Epoch 4/100
# 137/137 - 2s - loss: 1.2366 - accuracy: 0.4691
# Epoch 5/100
# 137/137 - 2s - loss: 1.2314 - accuracy: 0.4673
# Epoch 6/100
# 137/137 - 1s - loss: 1.2297 - accuracy: 0.4698
# Epoch 7/100
# 137/137 - 1s - loss: 1.2283 - accuracy: 0.4714
# Epoch 8/100
# 137/137 - 1s - loss: 1.2270 - accuracy: 0.4728
# Epoch 9/100
# 137/137 - 1s - loss: 1.2258 - accuracy: 0.4767
# Epoch 10/100
# 137/137 - 1s - loss: 1.2249 - accuracy: 0.4842
# Epoch 11/100
# 137/137 - 2s - loss: 1.2208 - accuracy: 0.4840
# Epoch 12/100
# 137/137 - 2s - loss: 1.2226 - accuracy: 0.4815
# Epoch 13/100
# 137/137 - 2s - loss: 1.2206 - accuracy: 0.4881
# Epoch 14/100
# 137/137 - 1s - loss: 1.2192 - accuracy: 0.4865
# Epoch 15/100
# 137/137 - 1s - loss: 1.2160 - accuracy: 0.4925
# Epoch 16/100
# 137/137 - 1s - loss: 1.2180 - accuracy: 0.4810
# Epoch 17/100
# 137/137 - 1s - loss: 1.2176 - accuracy: 0.4913
# Epoch 18/100
# 137/137 - 1s - loss: 1.2172 - accuracy: 0.4899
# Epoch 19/100
# 137/137 - 1s - loss: 1.2148 - accuracy: 0.4865
# Epoch 20/100
# 137/137 - 1s - loss: 1.2126 - accuracy: 0.4858
# Epoch 21/100
# 137/137 - 1s - loss: 1.2120 - accuracy: 0.4922
# Epoch 22/100
# 137/137 - 1s - loss: 1.2122 - accuracy: 0.4922
# Epoch 23/100
# 137/137 - 1s - loss: 1.2092 - accuracy: 0.4911
# Epoch 24/100
# 137/137 - 2s - loss: 1.2084 - accuracy: 0.4888
# Epoch 25/100
# 137/137 - 2s - loss: 1.2081 - accuracy: 0.4927
# Epoch 26/100
# 137/137 - 2s - loss: 1.2064 - accuracy: 0.4966
# Epoch 27/100
# 137/137 - 2s - loss: 1.2039 - accuracy: 0.5009
# Epoch 28/100
# 137/137 - 2s - loss: 1.2040 - accuracy: 0.4959
# Epoch 29/100
# 137/137 - 1s - loss: 1.2030 - accuracy: 0.4920
# Epoch 30/100
# 137/137 - 1s - loss: 1.2040 - accuracy: 0.4918
# Epoch 31/100
# 137/137 - 2s - loss: 1.2019 - accuracy: 0.4979
# Epoch 32/100
# 137/137 - 1s - loss: 1.2001 - accuracy: 0.4989
# Epoch 33/100
# 137/137 - 1s - loss: 1.1994 - accuracy: 0.4979
# Epoch 34/100
# 137/137 - 1s - loss: 1.1975 - accuracy: 0.5034
# Epoch 35/100
# 137/137 - 1s - loss: 1.1985 - accuracy: 0.4968
# Epoch 36/100
# 137/137 - 1s - loss: 1.1973 - accuracy: 0.4973
# Epoch 37/100
# 137/137 - 1s - loss: 1.1954 - accuracy: 0.4950
# Epoch 38/100
# 137/137 - 1s - loss: 1.1954 - accuracy: 0.5018
# Epoch 39/100
# 137/137 - 1s - loss: 1.1926 - accuracy: 0.4966
# Epoch 40/100
# 137/137 - 1s - loss: 1.1906 - accuracy: 0.4984
# Epoch 41/100
# 137/137 - 1s - loss: 1.1919 - accuracy: 0.4984
# Epoch 42/100
# 137/137 - 1s - loss: 1.1900 - accuracy: 0.4975
# Epoch 43/100
# 137/137 - 1s - loss: 1.1888 - accuracy: 0.4961
# Epoch 44/100
# 137/137 - 1s - loss: 1.1877 - accuracy: 0.5069
# Epoch 45/100
# 137/137 - 1s - loss: 1.1873 - accuracy: 0.5018
# Epoch 46/100
# 137/137 - 1s - loss: 1.1867 - accuracy: 0.4952
# Epoch 47/100
# 137/137 - 1s - loss: 1.1844 - accuracy: 0.5094
# Epoch 48/100
# 137/137 - 1s - loss: 1.1841 - accuracy: 0.5064
# Epoch 49/100
# 137/137 - 1s - loss: 1.1827 - accuracy: 0.5055
# Epoch 50/100
# 137/137 - 1s - loss: 1.1821 - accuracy: 0.5011
# Epoch 51/100
# 137/137 - 1s - loss: 1.1808 - accuracy: 0.5025
# Epoch 52/100
# 137/137 - 1s - loss: 1.1813 - accuracy: 0.4993
# Epoch 53/100
# 137/137 - 1s - loss: 1.1787 - accuracy: 0.5078
# Epoch 54/100
# 137/137 - 1s - loss: 1.1785 - accuracy: 0.5055
# Epoch 55/100
# 137/137 - 1s - loss: 1.1761 - accuracy: 0.5091
# Epoch 56/100
# 137/137 - 1s - loss: 1.1773 - accuracy: 0.5158
# Epoch 57/100
# 137/137 - 1s - loss: 1.1759 - accuracy: 0.5032
# Epoch 58/100
# 137/137 - 1s - loss: 1.1784 - accuracy: 0.5110
# Epoch 59/100
# 137/137 - 1s - loss: 1.1729 - accuracy: 0.5080
# Epoch 60/100
# 137/137 - 1s - loss: 1.1746 - accuracy: 0.5096
# Epoch 61/100
# 137/137 - 1s - loss: 1.1739 - accuracy: 0.5048
# Epoch 62/100
# 137/137 - 1s - loss: 1.1727 - accuracy: 0.5039
# Epoch 63/100
# 137/137 - 1s - loss: 1.1700 - accuracy: 0.5137
# Epoch 64/100
# 137/137 - 1s - loss: 1.1726 - accuracy: 0.5089
# Epoch 65/100
# 137/137 - 1s - loss: 1.1688 - accuracy: 0.5114
# Epoch 66/100
# 137/137 - 1s - loss: 1.1697 - accuracy: 0.5133
# Epoch 67/100
# 137/137 - 1s - loss: 1.1704 - accuracy: 0.5094
# Epoch 68/100
# 137/137 - 1s - loss: 1.1676 - accuracy: 0.5110
# Epoch 69/100
# 137/137 - 1s - loss: 1.1682 - accuracy: 0.5114
# Epoch 70/100
# 137/137 - 1s - loss: 1.1658 - accuracy: 0.5151
# Epoch 71/100
# 137/137 - 1s - loss: 1.1667 - accuracy: 0.5119
# Epoch 72/100
# 137/137 - 1s - loss: 1.1646 - accuracy: 0.5158
# Epoch 73/100
# 137/137 - 1s - loss: 1.1654 - accuracy: 0.5101
# Epoch 74/100
# 137/137 - 1s - loss: 1.1653 - accuracy: 0.5123
# Epoch 75/100
# 137/137 - 1s - loss: 1.1649 - accuracy: 0.5160
# Epoch 76/100
# 137/137 - 1s - loss: 1.1639 - accuracy: 0.5114
# Epoch 77/100
# 137/137 - 1s - loss: 1.1642 - accuracy: 0.5142
# Epoch 78/100
# 137/137 - 1s - loss: 1.1624 - accuracy: 0.5158
# Epoch 79/100
# 137/137 - 1s - loss: 1.1631 - accuracy: 0.5121
# Epoch 80/100
# 137/137 - 1s - loss: 1.1612 - accuracy: 0.5107
# Epoch 81/100
# 137/137 - 1s - loss: 1.1595 - accuracy: 0.5146
# Epoch 82/100
# 137/137 - 1s - loss: 1.1596 - accuracy: 0.5121
# Epoch 83/100
# 137/137 - 1s - loss: 1.1603 - accuracy: 0.5121
# Epoch 84/100
# 137/137 - 1s - loss: 1.1592 - accuracy: 0.5158
# Epoch 85/100
# 137/137 - 1s - loss: 1.1597 - accuracy: 0.5162
# Epoch 86/100
# 137/137 - 1s - loss: 1.1577 - accuracy: 0.5174
# Epoch 87/100
# 137/137 - 1s - loss: 1.1573 - accuracy: 0.5199
# Epoch 88/100
# 137/137 - 1s - loss: 1.1565 - accuracy: 0.5153
# Epoch 89/100
# 137/137 - 1s - loss: 1.1558 - accuracy: 0.5176
# Epoch 90/100
# 137/137 - 1s - loss: 1.1555 - accuracy: 0.5123
# Epoch 91/100
# 137/137 - 1s - loss: 1.1553 - accuracy: 0.5146
# Epoch 92/100
# 137/137 - 1s - loss: 1.1532 - accuracy: 0.5160
# Epoch 93/100
# 137/137 - 1s - loss: 1.1549 - accuracy: 0.5224
# Epoch 94/100
# 137/137 - 1s - loss: 1.1535 - accuracy: 0.5201
# Epoch 95/100
# 137/137 - 1s - loss: 1.1529 - accuracy: 0.5197
# Epoch 96/100
# 137/137 - 1s - loss: 1.1505 - accuracy: 0.5210
# Epoch 97/100
# 137/137 - 1s - loss: 1.1510 - accuracy: 0.5213
# Epoch 98/100
# 137/137 - 1s - loss: 1.1498 - accuracy: 0.5183
# Epoch 99/100
# 137/137 - 1s - loss: 1.1520 - accuracy: 0.5261
# Epoch 100/100
# 137/137 - 1s - loss: 1.1487 - accuracy: 0.5240

# %%
# Evaluating the Deep Model
deep_model_loss, deep_model_accuracy = deep_model.evaluate(X_test_scaled, one_hot_y_test, verbose=5)
print(f'Loss: {deep_model_loss}, Accuracy: {deep_model_accuracy}')
# Out:
# Loss: 1.4028315544128418, Accuracy: 0.4551062285900116
